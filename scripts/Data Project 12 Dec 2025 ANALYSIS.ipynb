# %%
import pandas as pd
import numpy as np

df = gpd.read_file("/data/MASTER_dataset CLEANED v2.geojson").drop(columns="geometry")

id_cols = ["geoid", "county_name", "city_name", "zcta", "tract_land_type"]

feature_cols = [
    "acs_population","acs_households","acs_median_hh_income","acs_avg_hh_size",
    "svi_overall_pctile","svi_overall_score",
    "svi_unemployed_pct","svi_housing_cost_burden_pct","svi_no_vehicle_pct",
    "svi_poverty_150pct_pct","svi_no_hs_diploma_pct","svi_limited_english_pct",
    "nri_top3_hazards_eal_total_usd",
    "nri_top3_eal_per_household_usd","nri_top3_eal_per_capita_usd",
    "nfhl_in_floodplain",
    "flood_hurricane_share_of_total_eal"
]

feature_cols = [c for c in feature_cols if c in df.columns]
df = df[id_cols + feature_cols].copy()
df.head()
# Out:
#          geoid county_name            city_name                  zcta  \
# 0  12011060303     Broward           Lauderhill                 33313
# 1  12086013600  Miami-Dade              Hialeah                 33016
# 2  12086013700  Miami-Dade      Hialeah Gardens                 33016
# 3  12086980100  Miami-Dade  Unincorporated Area  No ZCTA (Land tract)
# 4  12011110501     Broward              Miramar                 33023
#
#   tract_land_type  acs_population  acs_households  acs_median_hh_income  \
# 0            land          6883.0          2366.0               38319.0
# 1            land          5857.0          2011.0               44688.0
# 2            land          6199.0          2228.0               41081.0
# 3            land             NaN             NaN                   NaN
# 4            land          3996.0          1063.0               78599.0
#
#    acs_avg_hh_size  svi_overall_pctile  ...  svi_housing_cost_burden_pct  \
# ...

# %%
# Replace common sentinel values with NaN
sentinels = [-999, -9999, -666666666, -6666666666]
df = df.replace(sentinels, np.nan)

# Coerce numerics
for c in feature_cols:
    if c != "nfhl_in_floodplain":
        df[c] = pd.to_numeric(df[c], errors="coerce")

# Standardize floodplain to 0/1
if "nfhl_in_floodplain" in df.columns:
    df["nfhl_in_floodplain"] = df["nfhl_in_floodplain"].astype("boolean").fillna(False).astype(int)

df.describe(include="all").T.head(15)
# Out:
#                               count unique          top  freq          mean  \
# geoid                          1526   1526  12011060303     1           NaN
# county_name                    1526      4   Miami-Dade   707           NaN
# city_name                      1526    159        Miami   133           NaN
# zcta                           1526    193        33012    20           NaN
# tract_land_type                1526      3         land  1494           NaN
# acs_population               1506.0    NaN          NaN   NaN   4120.845286
# acs_households               1502.0    NaN          NaN   NaN   1543.698402
# acs_median_hh_income         1491.0    NaN          NaN   NaN  77972.244802
# acs_avg_hh_size              1502.0    NaN          NaN   NaN      2.676458
# svi_overall_pctile           1502.0    NaN          NaN   NaN      0.586494
# svi_overall_score            1502.0    NaN          NaN   NaN      8.377008
# ...

# %%
# Create income_loss_ratio
df["income_loss_ratio"] = np.where(
    (df["acs_median_hh_income"] > 0) & (df["nri_top3_eal_per_household_usd"] >= 0),
    df["nri_top3_eal_per_household_usd"] / df["acs_median_hh_income"],
    np.nan
)

# Create income_loss_category
bins = [-np.inf, 0.01, 0.03, np.inf]
labels = ["Low (<1%)", "Moderate (1–3%)", "High (≥3%)"]
df["income_loss_category"] = pd.cut(df["income_loss_ratio"], bins=bins, labels=labels)

# %%
df["high_financial_strain_flag"] = np.where(df["income_loss_ratio"] >= 0.03, 1, 0)

# %%
# Descriptive analysis
print("Tracts:", len(df))
print("Median income_loss_ratio:", df["income_loss_ratio"].median())
print("Share high strain (>=3%):", df["high_financial_strain_flag"].mean())

# By county
county_summary = (
    df.groupby("county_name", dropna=False)
      .agg(
          tracts=("geoid","count"),
          households=("acs_households","sum"),
          median_income=("acs_median_hh_income","median"),
          avg_loss_per_hh=("nri_top3_eal_per_household_usd","mean"),
          avg_strain=("income_loss_ratio","mean"),
          pct_high_strain=("high_financial_strain_flag","mean"),
      )
      .sort_values("avg_strain", ascending=False)
)
county_summary
# Out:
# Tracts: 1526
# Median income_loss_ratio: 0.009106833538889034
# Share high strain (>=3%): 0.03407601572739188
#              tracts  households  median_income  avg_loss_per_hh  avg_strain  \
# county_name
# Monroe           29     34388.0        85317.0      4927.855245    0.034899
# Miami-Dade      707    952680.0        66597.0      1619.731073    0.014338
# Broward         417    741973.0        70267.5       811.537235    0.011324
# Palm Beach      373    589594.0        76338.0       845.163168    0.010401
#
#              pct_high_strain
# county_name
# Monroe              0.413793
# Miami-Dade          0.035361
# Broward             0.016787
# Palm Beach          0.021448

# %%
# Correlation analysis
num_for_corr = [
    "income_loss_ratio",
    "acs_median_hh_income",
    "acs_households",
    "svi_overall_pctile",
    "svi_overall_score",
    "svi_unemployed_pct",
    "svi_housing_cost_burden_pct",
    "svi_no_vehicle_pct",
    "flood_hurricane_share_of_total_eal",
    "nri_top3_eal_per_household_usd"
]
num_for_corr = [c for c in num_for_corr if c in df.columns]

corr = df[num_for_corr].corr(numeric_only=True).sort_values("income_loss_ratio", ascending=False)
corr["income_loss_ratio"]
# Out:
# income_loss_ratio                     1.000000
# nri_top3_eal_per_household_usd        0.916595
# svi_no_vehicle_pct                    0.105575
# svi_overall_score                     0.062969
# svi_overall_pctile                    0.058850
# flood_hurricane_share_of_total_eal    0.029460
# svi_housing_cost_burden_pct           0.024159
# svi_unemployed_pct                   -0.007997
# acs_median_hh_income                 -0.053235
# acs_households                       -0.118116
# Name: income_loss_ratio, dtype: float64

# %%
# Segmentation analysis
# Top 10 cities by income loss
city_seg = df.dropna(subset=["city_name"]).copy()

city_seg["w"] = city_seg["acs_households"].clip(lower=0)

# household-weighted avg strain
city_rollup = (
    city_seg.groupby("city_name")
    .apply(lambda g: pd.Series({
        "households": g["acs_households"].sum(),
        "weighted_income_loss": np.average(g["income_loss_ratio"].dropna(), 
                                             weights=g.loc[g["income_loss_ratio"].notna(), "w"]),
        "weighted_loss_per_hh": np.average(g["nri_top3_eal_per_household_usd"].dropna(),
                                           weights=g.loc[g["nri_top3_eal_per_household_usd"].notna(), "w"]),
        "median_income": g["acs_median_hh_income"].median()
    }))
    .sort_values("weighted_income_loss", ascending=False)
)

city_rollup.head(10)
# Out:
# /var/folders/mv/5grglnm12qj9pj0l3s5k20_40000gn/T/ipykernel_57786/3339794560.py:10: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: pd.Series({
#                        households  weighted_income_loss  weighted_loss_per_hh  \
# city_name
# Canal Point                 952.0              0.109286           1796.763091
# Lake Harbor                 765.0              0.102421           5062.353630
# No city (Water tract)       487.0              0.064555           8236.519176
# Big Pine Key               1239.0              0.049794           3551.357872
# Tavernier                  1200.0              0.048393           2344.396164
# ...

# %%
# Regression analysis
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error

model_cols = ["income_loss_ratio", "svi_overall_pctile", "nri_top3_eal_per_household_usd", "nfhl_in_floodplain"]
model_cols = [c for c in model_cols if c in df.columns]

model_df = df[model_cols].dropna().copy()

X = model_df[["svi_overall_pctile", "nri_top3_eal_per_household_usd", "nfhl_in_floodplain"]]
y = model_df["income_loss_ratio"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

lr = LinearRegression().fit(X_train, y_train)
pred = lr.predict(X_test)

print("R2:", r2_score(y_test, pred))
print("MAE:", mean_absolute_error(y_test, pred))
print(pd.Series(lr.coef_, index=X.columns).sort_values(ascending=False))
# Out:
# R2: 0.49979951320195204
# MAE: 0.0036009314539876677
# svi_overall_pctile                0.020669
# nri_top3_eal_per_household_usd    0.000015
# nfhl_in_floodplain               -0.000832
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model_df = df[["high_financial_strain_flag","svi_overall_pctile","acs_median_hh_income","nfhl_in_floodplain"]].dropna()

X = model_df[["svi_overall_pctile","acs_median_hh_income","nfhl_in_floodplain"]]
y = model_df["high_financial_strain_flag"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = LogisticRegression(max_iter=200).fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("accuracy:", accuracy_score(y_test, y_pred))
print("precision:", precision_score(y_test, y_pred, zero_division=0))
print("recall:", recall_score(y_test, y_pred, zero_division=0))
print("f1:", f1_score(y_test, y_pred, zero_division=0))
# Out:
# accuracy: 0.9754464285714286
# precision: 0.0
# recall: 0.0
# f1: 0.0
